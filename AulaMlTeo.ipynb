# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/ml-aulas-py/blob/main/AulaMlTeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("/content/drive/MyDrive/DadosMlTeo/DadosMl/dados_cerveja_nota.xlsx")
print(df)
# Out:
#     id  cerveja   nota
# 0    1        1   0.75
# 1    2        1   3.00
# 2    3        2   1.75
# 3    4        3   1.75
# 4    5        4   4.20
# 5    6        4   6.50
# 6    7        5   2.90
# 7    8        6   6.20
# 8    9        6   7.00
# 9   10        7   6.20
# 10  11        8   8.50
# 11  12        8  10.00
# 12  13        9   8.60
# 13  14        9   9.90
# 14  15        9  10.00

# %%
X= df["cerveja"]
y = df["nota"]
X = np.array(X)
y = np.array(y)

# %%
# Criando gráfico de cervejas


plt.plot(X,y, 'o')
plt.grid(True)
plt.title("Relação Nota vs Cerveja")
plt.ylim(0, 11)
plt.xlim(0, 11)
plt.xlabel("Cerveja")
plt.ylabel("Nota")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Reshape X_train and y_train to 2D arrays
# Convert X and y to NumPy arrays
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=22)

# %%
# %%

# %%


# %%

from sklearn import linear_model


reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)

# %%
a, b = reg.intercept_, reg.coef_[0]
print(f"a={a}; b={b}")

# %%

y_estimado = reg.predict(X_test)
y_estimado

plt.plot(X_test, y_test, 'o')
plt.plot(X_test, y_test, '-')
plt.grid(True)
plt.title("Relação Nota vs Cerveja")
plt.ylim(0, 11)
plt.xlim(0, 11)
plt.xlabel("Cerveja")
plt.ylabel("Nota")
plt.show()

# %%


# %%
# Out:
# a=[0.36379468]; b=[0.99899175]

# %%
from sklearn import tree
arvore = tree.DecisionTreeRegressor(max_depth=2)
arvore.fit(X_train, y_train)

y_estimado_arvore = arvore.predict(X_test)

plt.figure(dpi=500)
plt.plot(X, y, 'o')
plt.plot(X_test, y_estimado, '-')
plt.plot(X_test, y_estimado_arvore, '-')
plt.grid(True)
plt.title("Relação Nota vs Cerveja")
plt.ylim(0, 11)
plt.xlim(0, 11)
plt.xlabel("Cerveja")
plt.ylabel("Nota")
plt.legend(["Observações", "Regressão Linear", "Árvore de Decisão"])
plt.show()
# %%
